# %%
import numpy as np
import pandas as pd
import warnings
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Concatenate, Embedding, Dense, Flatten
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model

warnings.filterwarnings('ignore')

# %%
def load_data(movie_path, rating_path):

    movie = pd.read_csv(movie_path)
    rating = pd.read_csv(rating_path)
    movie = movie.drop_duplicates()
    rating = rating.drop_duplicates()
    return movie, rating

def data_prep(movie_data, rating_data):

    data = rating_data.merge(movie_data, on = 'movieId', how = 'inner')
    group_df = data.groupby(['movieId']).count()
    idx = group_df[group_df.userId > 1000].index.to_list()
    data = data[data['movieId'].isin(idx)]
    return data

data_dir = './Data/archive (1)/'
rating_path = data_dir + 'rating.csv'
movie_path = data_dir + 'movie.csv'
movie_data, rating_data = load_data(movie_path, rating_path)
data = data_prep(movie_data, rating_data)

# %%
data.head()
# Out:
#    userId  movieId  rating            timestamp           title  \
# 0       1        2     3.5  2005-04-02 23:53:47  Jumanji (1995)
# 1       5        2     3.0  1996-12-25 15:26:09  Jumanji (1995)
# 2      13        2     3.0  1996-11-27 08:19:02  Jumanji (1995)
# 3      29        2     3.0  1996-06-23 20:36:14  Jumanji (1995)
# 4      34        2     3.0  1996-10-28 13:29:44  Jumanji (1995)
#
#                        genres
# 0  Adventure|Children|Fantasy
# 1  Adventure|Children|Fantasy
# 2  Adventure|Children|Fantasy
# 3  Adventure|Children|Fantasy
# 4  Adventure|Children|Fantasy

# %%
data['userId'] = pd.Categorical(data['userId'])
data['new_userid'] = data['userId'].cat.codes

data['movieId'] = pd.Categorical(data['movieId'])
data['new_movieid'] = data['movieId'].cat.codes

data['genres'] = pd.Categorical(data['genres'])
data['new_genres'] = data['genres'].cat.codes


data['title'] = pd.Categorical(data['title'])
data['new_title'] = data['title'].cat.codes

# %%
data.head()
# Out:
#   userId movieId  rating            timestamp           title  \
# 0      1       2     3.5  2005-04-02 23:53:47  Jumanji (1995)
# 1      5       2     3.0  1996-12-25 15:26:09  Jumanji (1995)
# 2     13       2     3.0  1996-11-27 08:19:02  Jumanji (1995)
# 3     29       2     3.0  1996-06-23 20:36:14  Jumanji (1995)
# 4     34       2     3.0  1996-10-28 13:29:44  Jumanji (1995)
#
#                        genres  new_userid  new_movieid  new_genres  new_title
# 0  Adventure|Children|Fantasy           0            1         262       1523
# 1  Adventure|Children|Fantasy           4            1         262       1523
# 2  Adventure|Children|Fantasy          12            1         262       1523
# 3  Adventure|Children|Fantasy          28            1         262       1523
# 4  Adventure|Children|Fantasy          33            1         262       1523

# %%
df = data[['new_userid','new_movieid', 'rating', 'new_genres']]
df = df.drop_duplicates()

#df.head()

# %%
U = len(set(df['new_userid'].values))
M = len(set(df['new_movieid'].values))
G = len(set(df['new_genres'].values))
k = 20

id = Input(shape = (1,))
movie = Input(shape = (1,))
gen = Input(shape = (1,))

emb_id = Embedding(U, k)(id)
emb_movie = Embedding(M, k)(movie)
emb_genre = Embedding(G, k)(gen)

flatten_id = Flatten()(emb_id)
flatten_movie = Flatten()(emb_movie)
flatten_genre = Flatten()(emb_genre)

emb = Concatenate()([flatten_id, flatten_movie, flatten_genre])
dense = Dense(64, activation = 'relu')(emb)
dense_1 = Dense(1)(dense)
model = Model(inputs = [id, movie, gen], outputs = dense)
model.compile(optimizer = 'Adam',metrics = ['MeanSquaredError'] ,loss = 'mse')

# %%
train_data, test_data = train_test_split(df, test_size= 0.3, random_state=0)
userid_train = train_data['new_userid'].values
movieid_train = train_data['new_movieid'].values
gen_train = train_data['new_genres'].values
train_y = train_data['rating'].values

userid_test = test_data['new_userid'].values
movieid_test = test_data['new_movieid'].values
gen_test = test_data['new_genres'].values
test_y = test_data['rating'].values

hist = model.fit(x=[userid_train, movieid_train, gen_train],
                 y= train_y,
                 epochs = 20,
                 batch_size = 2048,
                validation_data = ([userid_test, movieid_test, gen_test], test_y) )
# Out:
# Epoch 1/20
# 6073/6073 [==============================] - 488s 80ms/step - loss: 1.0409 - mean_squared_error: 1.0409 - val_loss: 0.7455 - val_mean_squared_error: 0.7455
# Epoch 2/20
# 6073/6073 [==============================] - 634s 104ms/step - loss: 0.7379 - mean_squared_error: 0.7379 - val_loss: 0.7411 - val_mean_squared_error: 0.7411
# Epoch 3/20
# 6073/6073 [==============================] - 467s 77ms/step - loss: 0.7335 - mean_squared_error: 0.7335 - val_loss: 0.7394 - val_mean_squared_error: 0.7394
# Epoch 4/20
# 6073/6073 [==============================] - 805s 132ms/step - loss: 0.7310 - mean_squared_error: 0.7310 - val_loss: 0.7383 - val_mean_squared_error: 0.7383
# Epoch 5/20
# 6073/6073 [==============================] - 596s 98ms/step - loss: 0.7294 - mean_squared_error: 0.7294 - val_loss: 0.7376 - val_mean_squared_error: 0.7376
# Epoch 6/20
# 6073/6073 [==============================] - 741s 122ms/step - loss: 0.7281 - mean_squared_error: 0.7281 - val_loss: 0.7372 - val_mean_squared_error: 0.7372
# Epoch 7/20
# 6073/6073 [==============================] - 560s 92ms/step - loss: 0.7272 - mean_squared_error: 0.7272 - val_loss: 0.7368 - val_mean_squared_error: 0.7368
# Epoch 8/20
# 6073/6073 [==============================] - 610s 101ms/step - loss: 0.7264 - mean_squared_error: 0.7264 - val_loss: 0.7369 - val_mean_squared_error: 0.7369
# Epoch 9/20
# 6073/6073 [==============================] - 608s 100ms/step - loss: 0.7257 - mean_squared_error: 0.7257 - val_loss: 0.7362 - val_mean_squared_error: 0.7362
# Epoch 10/20
# 6073/6073 [==============================] - 602s 99ms/step - loss: 0.7252 - mean_squared_error: 0.7252 - val_loss: 0.7358 - val_mean_squared_error: 0.7358
# Epoch 11/20
# 6073/6073 [==============================] - 555s 91ms/step - loss: 0.7247 - mean_squared_error: 0.7247 - val_loss: 0.7358 - val_mean_squared_error: 0.7358
# Epoch 12/20
# 6073/6073 [==============================] - 527s 87ms/step - loss: 0.7243 - mean_squared_error: 0.7243 - val_loss: 0.7357 - val_mean_squared_error: 0.7357
# Epoch 13/20
# 6073/6073 [==============================] - 580s 95ms/step - loss: 0.7238 - mean_squared_error: 0.7238 - val_loss: 0.7355 - val_mean_squared_error: 0.7355
# Epoch 14/20
# 6073/6073 [==============================] - 673s 111ms/step - loss: 0.7235 - mean_squared_error: 0.7235 - val_loss: 0.7359 - val_mean_squared_error: 0.7359
# Epoch 15/20
# 6073/6073 [==============================] - 536s 88ms/step - loss: 0.7232 - mean_squared_error: 0.7232 - val_loss: 0.7353 - val_mean_squared_error: 0.7353
# Epoch 16/20
# 6073/6073 [==============================] - 498s 82ms/step - loss: 0.7229 - mean_squared_error: 0.7229 - val_loss: 0.7358 - val_mean_squared_error: 0.7358
# Epoch 17/20
# 6073/6073 [==============================] - 523s 86ms/step - loss: 0.7227 - mean_squared_error: 0.7227 - val_loss: 0.7351 - val_mean_squared_error: 0.7351
# Epoch 18/20
# 6073/6073 [==============================] - 435s 72ms/step - loss: 0.7224 - mean_squared_error: 0.7224 - val_loss: 0.7351 - val_mean_squared_error: 0.7351
# Epoch 19/20
# 6073/6073 [==============================] - 447s 74ms/step - loss: 0.7222 - mean_squared_error: 0.7222 - val_loss: 0.7356 - val_mean_squared_error: 0.7356
# Epoch 20/20
# 6073/6073 [==============================] - 432s 71ms/step - loss: 0.7220 - mean_squared_error: 0.7220 - val_loss: 0.7352 - val_mean_squared_error: 0.7352
